# %%
pip install Matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import sklearn

# %% [markdown]
# ***test 3:***
# simple liner regression and multiple,
# logistic regression,
# KNN,
# SVM,
#
#
# ***test 4:***
# polynomila regression,
# decison tree,
# carnal SVM,
# Random Forest,
# Adaboost,
# ensemble leraning,
# navie base classifer

# %%
|2||3||5|
# Out:
#   Cell In[21], line 1
#     |2||3||5|
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# |2|3|4|
# |-|-|-|
# |21|32||
