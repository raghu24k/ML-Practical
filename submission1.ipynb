# %% [markdown]
# <!-- ## TUTORIAL 2 - EXPLORE PANDAS LIBRARY TO ANALYZE AND MANIIPULATE DATA. -->

# %% [markdown]
# <!-- pandas is an open - source library fo rreal world data analysis in python. it is built on toop of
# numpy. using pandas, data can be cleaned, transformed, manipulated, and analyzed.
# The basic data structures of pandas are series and DataFrame.
# 1. Series object Sries is a one dimensional labled array.
# 2. DataFame: A DataFrame in pandas is a two-dimesional, tabular data structure.
# it consists of rows and columns.
# columns represents different features.
# rows represents records or entries.
# index means label of rows. -->

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# <!-- # HOME WORK
# find out the difference list and numpy 1d array and pandas series -->

# %%
a  = np.array([1,2,3,4,5])
# a  = np.array([1,2,3,4,5])
print(a)
# Out:
# [1 2 3 4 5]

# %%
s1 = pd.Series([1,2,3,4,5],['a','b','c','d','e'])
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s1.values
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
data = [{'Name':'Raghu','Marks': 87},
        {'Name':'Sita','Marks': 92},
        {'Name':'Gita','Marks': 78}]
ds = pd.DataFrame(data)
print(ds)
# Out:
#     Name  Marks
# 0  Raghu     87
# 1   Sita     92
# 2   Gita     78

# %%
type(data)
# Out:
# list

# %%
# Check for missing values in the DataFrame
ds.isna().sum()
# Out:
# Name     0
# Marks    0
# dtype: int64

# %%
read _excel
# Out:
#   Cell In[22], line 1
#     read _excel
#          ^
# SyntaxError: invalid syntax

# %%
filepath = "submission1.xlsx"

# %%
student_data= pd.read_excel("submission1.xlsx")
student_data
# Out:
#        Name   Branch Divison
# 0     RAGHU       CE       A
# 1     VIKAS  MEDICAL       C
# 2    VISHAL    MUSIC       A
# 3  KARADEEP    B.COM       B

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
iris = pd.read_csv("iris.csv",index_col=0)
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.head(15)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa
# 6             5.4           3.9            1.7           0.4  Iris-setosa
# 7             4.6           3.4            1.4           0.3  Iris-setosa
# 8             5.0           3.4            1.5           0.2  Iris-setosa
# 9             4.4           2.9            1.4           0.2  Iris-setosa
# 10            4.9           3.1            1.5           0.1  Iris-setosa
# 11            5.4           3.7            1.5           0.2  Iris-setosa
# 12            4.8           3.4            1.6           0.2  Iris-setosa
# ...

# %%
iris.tail(10)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 141            6.7           3.1            5.6           2.4  Iris-virginica
# 142            6.9           3.1            5.1           2.3  Iris-virginica
# 143            5.8           2.7            5.1           1.9  Iris-virginica
# 144            6.8           3.2            5.9           2.3  Iris-virginica
# 145            6.7           3.3            5.7           2.5  Iris-virginica
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica

# %%
iris.index[0]
# Out:
# 1

# %%
iris.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris = iris.rename(columns={'spalength':'sepal_length','spawidth':'sepal_width',
                            'petallength':'petal_length','petalwidth':'petal_width','species':'species'})
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
cat = iris["Species"].unique()
cat
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# iris.replace("iris-setosa","setosa",inplace=True)
# iris.replace("iris-versicolor","versicolor",inplace=True)
# iris.replace("iris-virginica","virginica",inplace=True)

# %%
iris.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
iris['SepalLengthCm']
# Out:
# Id
# 1      5.1
# 2      4.9
# 3      4.7
# 4      4.6
# 5      5.0
#       ...
# 146    6.7
# 147    6.3
# 148    6.5
# 149    6.2
# 150    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
iris.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris[['SepalLengthCm','SepalWidthCm']].head()
# Out:
#     SepalLengthCm  SepalWidthCm
# Id
# 1             5.1           3.5
# 2             4.9           3.0
# 3             4.7           3.2
# 4             4.6           3.1
# 5             5.0           3.6

# %%
def yes_no(sepal_length):
    return 'yes' if sepal_length > 5 else 'no'
# apply function to create new column
iris['resutl'] = iris['SepalLengthCm'].apply(yes_no)
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
#     resutl
# Id
# ...

# %%
# iris.drop('result',axis=1,inplace=True)
# iris
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 iris.drop('result',axis=1,inplace=True)
#       2 iris
#
# File c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
# ...

# %% [markdown]
# <!-- the .iloc indexer is primarily used for integer location based indexing,
# #allowing you to access specific rows and columns by their numerical indices. -->

# %%
iris.iloc[0]
# Out:
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# resutl                   yes
# Name: 1, dtype: object

# %%
iris.iloc[50:56]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species  \
# Id
# 51            7.0           3.2            4.7           1.4  Iris-versicolor
# 52            6.4           3.2            4.5           1.5  Iris-versicolor
# 53            6.9           3.1            4.9           1.5  Iris-versicolor
# 54            5.5           2.3            4.0           1.3  Iris-versicolor
# 55            6.5           2.8            4.6           1.5  Iris-versicolor
# 56            5.7           2.8            4.5           1.3  Iris-versicolor
#
#    resutl
# Id
# 51    yes
# 52    yes
# 53    yes
# 54    yes
# 55    yes
# 56    yes

# %%
iris.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species', 'resutl'],
#       dtype='object')

# %%
iris[(iris['PetalLengthCm'] > 6) & (iris['Species'] == 'virginica')]
# Out:
# Empty DataFrame
# Columns: [SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species, resutl]
# Index: []

# %%
student_data.to_csv("./dataset/student_info.csv")

# %%
student_data = pd.read_csv("./dataset/student_info.csv")

# %%
student_data
# Out:
#    Unnamed: 0      Name   Branch Divison
# 0           0     RAGHU       CE       A
# 1           1     VIKAS  MEDICAL       C
# 2           2    VISHAL    MUSIC       A
# 3           3  KARADEEP    B.COM       B

# %%
student['study_hours'] = student['study_hours'].fillna(student['study_hours'].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'study_hours'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[99], line 1
# ...

# %%
pip install ucimlrepo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
adult = fetch_ucirepo(id=2) 
  
# data (as pandas dataframes) 
X = adult.data.features 
y = adult.data.targets 
  
# metadata 
print(adult.metadata) 
  
# variable information 
print(adult.variables)
# Out:
# {'uci_id': 2, 'name': 'Adult', 'repository_url': 'https://archive.ics.uci.edu/dataset/2/adult', 'data_url': 'https://archive.ics.uci.edu/static/public/2/data.csv', 'abstract': 'Predict whether annual income of an individual exceeds $50K/yr based on census data. Also known as "Census Income" dataset. ', 'area': 'Social Science', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 48842, 'num_features': 14, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Age', 'Income', 'Education Level', 'Other', 'Race', 'Sex'], 'target_col': ['income'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1996, 'last_updated': 'Tue Sep 24 2024', 'dataset_doi': '10.24432/C5XW20', 'creators': ['Barry Becker', 'Ronny Kohavi'], 'intro_paper': None, 'additional_info': {'summary': "Extraction was done by Barry Becker from the 1994 Census database.  A set of reasonably clean records was extracted using the f
# ...

# %%
X.info
# Out:
# <bound method DataFrame.info of        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64               NaN  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# ...

# %%
X
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64               NaN  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# ...

# %%
X['workclass'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked',
#        nan], dtype=object)

# %%
X['occupation'].unique()
# i want to to print no of coulumns in occupation
print(len(X['occupation'].unique()))
# print(X['occupation'].unique())
# Out:
# 16

# %%
X.loc[:,"workclass"]=X['workclass'].fillna(X['workclass'].mode()[0])

# %%
X.loc[:,"occupation"]=X['occupation'].fillna(X['occupation'].mode()[0])

# %%
X.isna().sum()
# Out:
# age                 0
# workclass           0
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        966
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country    274
# dtype: int64

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df['Source_city'].

# %%
df['class'].unique()

# %% [markdown]
# 1. CountPlot
# Count ploat is used when you have categorial variables , and you want to visualize the distribution of these categories.

# %%
sns.countplot(x='class', data='df')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 sns.countplot(x='class', data='df')
#
# NameError: name 'sns' is not defined

# %% [markdown]
# 2. Piechart
# A pie chart represents the parts of a whole entity  . the entire pie represents 100% , and each slice represents a proportion or percentage of the whole
