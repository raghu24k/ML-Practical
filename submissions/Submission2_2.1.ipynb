# %% [markdown]
# ## Exercise 1: Implement Simple Linear Regression

# %% [markdown]
# Use the computers.csv dataset and perform the following activities:
#
# Dataset contains the details of time taken to repair a computer, given the number of units to be repaired.
#
# Dataset: Download from drive link
#
#   1.Build Regression model using Scikit-Learn Library(Model 3).
#       a.Set the 'Units' column as the input data or predictor column
#
#       b.Set the 'Minutes' column as the output data
#
#       c.Importing the required class -  LinearRegression
#
#       d.Creating a linear regression model
#
#       e.Fitting the model to the data
#
#       f.Fetching intercept and coefficient
#
#   2.Creating Linear Regression model with calculated coefficient and intercept.
#
#   3.Add the above model to the dataframe for Visualization.
#    Visualize Models using pyplot.
#
#   4.Compute the Coefficient of Determination to find accuracy

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\raghu\appdata\local\programs\python\python312\lib\site-packages (2.4.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\raghu\appdata\local\programs\python\python312\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\raghu\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\raghu\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\raghu\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\raghu\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\raghu\appdata\local\programs\python\python312\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\raghu\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.4.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\raghu\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\raghu\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\raghu\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
# df = pd.read_csv('./dataset/computers.csv')

# %%
computers = pd.read_csv('../dataset/computers.csv')

# %%
computers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Units    14 non-null     int64
#  1   Minutes  14 non-null     int64
# dtypes: int64(2)
# memory usage: 356.0 bytes

# %%
computers.tail()
# Out:
#     Units  Minutes
# 9       8      119
# 10      9      149
# 11      9      145
# 12     10      154
# 13     10      166

# %%
computers.isna().sum()
# Out:
# Units      0
# Minutes    0
# dtype: int64

# %%
mean_values = computers['Minutes'].mean()
mean_values
# Out:
# np.float64(97.21428571428571)

# %%
plt.scatter(computers['Units'],computers['Minutes'],color='blue')
plt.xlabel('Units')
plt.ylabel('Minutes')
# Out:
# Text(0, 0.5, 'Minutes')

# %%
model0=computers['Minutes'].mean()
model0
# Out:
# np.float64(97.21428571428571)

# %%
model1=10 + 12 *computers['Units']
model1
# Out:
# 0      22
# 1      34
# 2      46
# 3      58
# 4      58
# 5      70
# 6      82
# 7      82
# 8      94
# 9     106
# 10    118
# 11    118
# 12    130
# 13    130
# Name: Units, dtype: int64

# %%
model2 = 6 + 18 *computers['Units']

# %%
computers ['Model_0'] = model0
computers ['Model_1'] = model1
computers ['Model_2'] = model2

# %%
computers
# Out:
#     Units  Minutes    Model_0  Model_1  Model_2
# 0       1       23  97.214286       22       24
# 1       2       29  97.214286       34       42
# 2       3       49  97.214286       46       60
# 3       4       64  97.214286       58       78
# 4       4       74  97.214286       58       78
# 5       5       87  97.214286       70       96
# 6       6       96  97.214286       82      114
# 7       6       97  97.214286       82      114
# 8       7      109  97.214286       94      132
# 9       8      119  97.214286      106      150
# 10      9      149  97.214286      118      168
# 11      9      145  97.214286      118      168
# 12     10      154  97.214286      130      186
# 13     10      166  97.214286      130      186

# %%
fig,ax= plt.subplots()

# %%
fig,ax= plt.subplots()
ax.scatter(x='Units',y='Minutes',data=computers,label="actual repair time")

# %%
fig,ax= plt.subplots()
ax.scatter(x='Units',y='Minutes',data=computers,label="actual repair time")
ax.plot(computers['Units'],computers['Model_0'],color='red',label='Model0')
ax.plot(computers['Units'],computers['Model_1'],color='yellow',label='Model1')
ax.plot(computers['Units'],computers['Model_2'],color='blue',label='Model2')

# %% [markdown]
# ## Building the regression model using Scikit_learn Library

# %%
X = computers[['Units']]
y = computers['Minutes']
from sklearn.linear_model import LinearRegression
model3 = LinearRegression()
model3.fit(X, y)
print("Intercept:" , model3.intercept_)
print("Coefficients:" , model3.coef_)
# Out:
# Intercept: 4.161654135338296
# Coefficients: [15.50877193]

# %%
Model_3 = 4.16 + 15.50 *computers['Units']
computers ['Model_3'] = Model_3
computers
# Out:
#     Units  Minutes    Model_0  Model_1  Model_2  Model_3
# 0       1       23  97.214286       22       24    19.66
# 1       2       29  97.214286       34       42    35.16
# 2       3       49  97.214286       46       60    50.66
# 3       4       64  97.214286       58       78    66.16
# 4       4       74  97.214286       58       78    66.16
# 5       5       87  97.214286       70       96    81.66
# 6       6       96  97.214286       82      114    97.16
# 7       6       97  97.214286       82      114    97.16
# 8       7      109  97.214286       94      132   112.66
# 9       8      119  97.214286      106      150   128.16
# 10      9      149  97.214286      118      168   143.66
# 11      9      145  97.214286      118      168   143.66
# 12     10      154  97.214286      130      186   159.16
# 13     10      166  97.214286      130      186   159.16

# %%
fig,ax= plt.subplots()
ax.scatter(x='Units',y='Minutes',data=computers,label="actual repair time")
ax.plot(computers['Units'],computers['Model_0'],color='red',label='Model0')
ax.plot(computers['Units'],computers['Model_1'],color='yellow',label='Model1')
ax.plot(computers['Units'],computers['Model_2'],color='blue',label='Model2')
ax.plot(computers['Units'],computers['Model_3'],color='green',label='Model3')

# %%
rsq = model3.score(computers[['Units']],y)* 100

# %%
rsq
# Out:
# 98.74371980620737

# %% [markdown]
# ## Exercise 2: Multiple Linear Regression Model

# %% [markdown]
# std_marks_data.csv
#
# To understand Multiple Linear Regression, let us consider the student marks dataset.
#
#         This model helps us to predict the marks of the students using the previous dataset.
#
#         The inputs are hours(time spent to study) ,age(present age) and internet(weather the internet is available or not), by using these 3 input fields we are predicting the marks of the students.
#
#     1.Observe data and do some preprocessing.
#
#     2.Find no. of missing values.
#
#     3.Fill mean value in place of NaN value so NaN value does not affect accuracy.
#
#     4.Segregate input and output.
#
#     5.Prepare model.
#
#     6.Test model with new input data.

# %%
student=pd.read_csv('./dataset/std_marks_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 student=pd.read_csv('./dataset/std_marks_data.csv')
#
# File c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './dataset/std_marks_data.csv'

# %%
student.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   hours     288 non-null    float64
#  1   age       300 non-null    int64
#  2   internet  300 non-null    int64
#  3   marks     300 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 9.5 KB

# %%
student.head()
# Out:
#    hours  age  internet  marks
# 0   6.84   15         0  78.64
# 1   6.56   20         1  88.80
# 2    NaN   21         1  88.90
# 3   8.67   22         1  98.99
# 4   7.55   17         1  92.34

# %%
student.isna().sum()
# Out:
# hours       12
# age          0
# internet     0
# marks        0
# dtype: int64

# %%
student
# Out:
#      hours  age  internet  marks
# 0     6.84   15         0  78.64
# 1     6.56   20         1  88.80
# 2      NaN   21         1  88.90
# 3     8.67   22         1  98.99
# 4     7.55   17         1  92.34
# ..     ...  ...       ...    ...
# 295   2.99   25         0  43.45
# 296   6.55   15         1  77.74
# 297   0.00   20         1  75.76
# 298   9.90   22         0  99.99
# 299   3.40   21         0  99.99
#
# [300 rows x 4 columns]

# %%
student.hours =student.hours.fillna(student.hours.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 student.hours =student.hours.fillna(student.hours.mean())
#
# NameError: name 'student' is not defined

# %%
student.isna().sum()
# Out:
# hours       0
# age         0
# internet    0
# marks       0
# dtype: int64

# %%
X = student.iloc[:,-1]

# %%
X = student.iloc[:,:-1]

# %%
X.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   hours     300 non-null    float64
#  1   age       300 non-null    int64
#  2   internet  300 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 7.2 KB

# %%
X
# Out:
#         hours  age  internet
# 0    6.840000   15         0
# 1    6.560000   20         1
# 2    5.494514   21         1
# 3    8.670000   22         1
# 4    7.550000   17         1
# ..        ...  ...       ...
# 295  2.990000   25         0
# 296  6.550000   15         1
# 297  0.000000   20         1
# 298  9.900000   22         0
# 299  3.400000   21         0
#
# [300 rows x 3 columns]

# %%
y = student.iloc[:,-1]

# %%
y
# Out:
# 0      78.64
# 1      88.80
# 2      88.90
# 3      98.99
# 4      92.34
#        ...
# 295    43.45
# 296    77.74
# 297    75.76
# 298    99.99
# 299    99.99
# Name: marks, Length: 300, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size = 0.2)

# %%
X_train.shape
# Out:
# (240, 3)

# %%
X_test.shape
# Out:
# (60, 3)

# %%
y_train.shape
# Out:
# (240,)

# %%
y_test.shape
# Out:
# (60,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Intercept :" ,model.intercept_,"\nCoefficient :",model.coef_)
# Out:
# Intercept : 52.761209768487035
# Coefficient : [1.64232208 0.50765546 3.16299755]

# %%
hours=int(input("Enter study hours:"))
age=int(input("Enter age:"))
internet=(int(input("enter internet is available or not (0/1)")))
data=[[hours,age,internet]]
print(model.predict(data))
# Out:
# [68.70013504]
# c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Exercise 3: Build Logistic Regression Model

# %% [markdown]
# Consider a coronary heart disease dataset (chd_data.csv) which lists the age in years ('age') and the presence/absence of evidence of significant coronary heart disease ('chd') for 100 patients.
#
# The variable chd = 0 indicates the absence of coronary heart disease, whereas chd=1 indicates the presence of coronary heart disease.
#
#
# 1.Import dataset and visualize the data to get an insight on building the model.
#
# 2.Importing the required class
#
# 3.Specifying the columns as predictor and target variable
#
# 4.Split the data in training and test set in 70:30 ratio.
#
# 5.Built model using sklearn.linear_model.LogisticRegression class.
#
# 6.Train the model using the training data.
#
# 7.Fetch the intercept and the coefficients of the model.
#
# 8.Creating sample data.
#
# 9.Predicting the probabilities for each of the class labels.
#
# 10.Evaluate the model's performance on training and test data using 'accuracy' measure.

# %%
chd=pd.read_csv('./dataset/chd_data.csv')

# %%
chd
# Out:
#     age  chd
# 0    20    0
# 1    23    0
# 2    24    0
# 3    25    1
# 4    25    0
# ..  ...  ...
# 95   63    1
# 96   64    1
# 97   64    0
# 98   65    1
# 99   69    1
#
# [100 rows x 2 columns]

# %%
chd .info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     100 non-null    int64
#  1   chd     100 non-null    int64
# dtypes: int64(2)
# memory usage: 1.7 KB

# %%
chd.isna().sum()
# Out:
# age    0
# chd    0
# dtype: int64

# %%
import matplotlib

# %%
chd.shape
# Out:
# (100, 2)

# %%
plt.scatter("age","chd",data=chd)
plt.xlabel("age")
plt.ylabel("chd")
plt.title("Age vs. Coronory Heart Disease")
# Out:
# Text(0.5, 1.0, 'Age vs. Coronory Heart Disease')

# %%
#Importing required class
from sklearn.model_selection import train_test_split
#Specifying the columns as predictor and target variable
predictor=["age"]
target=["chd"]
X=chd[["age"]]# x contains the predictor values or input data
y=chd[["chd"]] # y contains the target labels
#Spilting the data into training and testing
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)
print("Shape of X_train:",X_train.shape)
print("Shape of y_train:",y_train.shape)
print("Shape of X_test:",X_test.shape)
print("Shape of y_test:",y_test.shape)
# Out:
# Shape of X_train: (70, 1)
# Shape of y_train: (70, 1)
# Shape of X_test: (30, 1)
# Shape of y_test: (30, 1)

# %%
#importing the required class
from sklearn.linear_model import LogisticRegression
#Creating the object of tthe class logisticRegression
model=LogisticRegression()
#Training the model using the training data
model.fit(X_train,y_train)
#Getting the intercept and the coefficient of the model
print("Intercept:",model.intercept_,"\nCoefficient:",model.coef_)
# Out:
# Intercept: [-5.6511192]
# Coefficient: [[0.11144141]]
# c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#Craeting a sample data
#test = np.array[29].reshaped (1,-1)
test=int(input("Enter age"))
data=[[test]]
print("\nPredicted class",model.predict(data))
# Out:
# Predicted class [0]
# c:\Users\raghu\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
model.score(X_train,y_train)
# Out:
# 0.7428571428571429

# %%
model.score(X_test,y_test)
# Out:
# 0.7333333333333333

# %%
#f1_score
from sklearn.metrics import f1_score
y_pred=model.predict(X_test)
f1=f1_score(y_test,y_pred)
f1
# Out:
# 0.7142857142857143

# %%
recall = sklearn.metrics.recall_score(y_test, y_pred)
recall
# Out:
# 0.5882352941176471

# %%
precision = sklearn.metrics.precision_score(y_test, y_pred)
precision
# Out:
# 0.9090909090909091
